# %%
import numpy as np

# %%
# we need to write our library on top of our jupyter notebook(not always :P)
x1 = np.random.randint(10, size=6)  # One-dimensional array
x2 = np.random.randint(10, size=(3, 4))  # Two-dimensional array
x3 = np.random.randint(10, size=(3, 4, 5))  # Three-dimensional array
print("x1 ndimension: ", x3.ndim)
print("x3 shape:", x3.shape)
print("x3 size: ", x3.size)
x3
# Out:
# x1 ndimension:  3
# x3 shape: (3, 4, 5)
# x3 size:  60
# array([[[0, 8, 0, 2, 1],
#         [9, 3, 4, 9, 2],
#         [1, 3, 9, 2, 2],
#         [9, 4, 3, 6, 5]],
#
#        [[5, 0, 4, 6, 5],
#         [8, 5, 9, 2, 6],
#         [9, 5, 7, 7, 4],
#         [5, 9, 6, 1, 4]],
#
#        [[7, 2, 5, 1, 3],
#         [0, 4, 4, 1, 6],
#         [2, 7, 2, 0, 0],
#         [4, 9, 7, 3, 0]]])

# %%
import matplotlib.pyplot as plt
plt.ylabel('my favorite numbers')
plt.xlabel('my favorite xlabel')

plt.plot([3, 4, 9,10 , 23,25])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Fixing random state for reproducibility
x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="r", alpha=0.8, marker=r'$\clubsuit$',
            label="Ogul")
plt.xlabel("Silver")
plt.ylabel("Gold")
plt.legend(loc='upper left')
plt.show()

# %%
# Library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Basic chart
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101) })
plt.plot( 'x', 'y', data=df, linestyle='none', marker='*')
 
# Annotate with text + Arrow
plt.annotate(
# Label and coordinate
'This point is interesting!', xy=(25, 50), xytext=(0, 200),

# Custom arrow
arrowprops=dict(facecolor='green', shrink=0.5)
)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: Second argument 'y' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
# Text(0, 200, 'This point is interesting!')

# %%
# Let’s study on more interesting example where we can use it
plt.plot([1,2,3,4,5], [1,2,3,4,10], 'ro')
plt.plot([1,2,3,4,5], [2,3,4,5,11], 'b-')
#DEFINITION = plt.plot([PLACES OF X],[PLACES OF Y],’type of mark’)
plt.title('MY Scatterplot')   # name of your graph
plt.xlabel('X axis')  # name your x axis
plt.ylabel('Y axis')   # name your y axis
plt.show()   # this command must be in the end to show the results

# %%
# Sample Decision Tree Classifier
from sklearn import datasets
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
# load the iris datasets
dataset = datasets.load_iris()
# fit a CART model to the data
model = DecisionTreeClassifier()
model.fit(dataset.data, dataset.target) # training data and testing data
print(model)
# make predictions
expected = dataset.target
predicted = model.predict(dataset.data)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))  ## result measurement
print(metrics.confusion_matrix(expected, predicted))
# Out:
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        50
#            2       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150
#
# [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
myData = np.random.randint(1, 9, (100 ,4)) # implement
myData # show the data
myData.shape
# Out:
# (100, 4)

# %%
myData
# Out:
# array([[6, 2, 6, 4],
#        [8, 8, 1, 4],
#        [4, 7, 4, 8],
#        [5, 7, 3, 3],
#        [5, 3, 2, 3],
#        [5, 4, 6, 6],
#        [6, 2, 1, 3],
#        [2, 8, 5, 5],
#        [7, 7, 4, 3],
#        [3, 5, 4, 2],
#        [3, 5, 3, 8],
#        [6, 2, 5, 4],
#        [7, 2, 7, 8],
#        [8, 4, 5, 2],
#        [2, 6, 4, 1],
#        [6, 1, 6, 6],
#        [7, 5, 7, 5],
#        [5, 8, 1, 6],
#        [7, 2, 4, 4],
#        [6, 2, 2, 1],
#        [7, 3, 8, 2],
#        [2, 8, 1, 1],
#        [5, 6, 8, 7],
#        [4, 4, 1, 6],
#        [8, 3, 4, 5],
#        [7, 6, 6, 5],
#        [4, 1, 1, 1],
#        [6, 6, 2, 7],
#        [5, 4, 4, 4],
#        [7, 2, 5, 6],
#        [3, 5, 6, 8],
#        [3, 3, 3, 7],
#        [2, 3, 7, 3],
#        [1, 3, 4, 2],
#        [6, 2, 7, 6],
#        [5, 4, 1, 3],
#        [5, 1, 6, 3],
#        [7, 8, 7, 2],
#        [8, 8, 5, 5],
#        [2, 7, 5, 2],
#        [5, 3, 5, 7],
#        [5, 1, 8, 8],
#        [8, 4, 3, 4],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scalar_model = MinMaxScaler()
scalar_model.fit_transform(myData)
# Out:
# array([[0.71428571, 0.14285714, 0.71428571, 0.42857143],
#        [1.        , 1.        , 0.        , 0.42857143],
#        [0.42857143, 0.85714286, 0.42857143, 1.        ],
#        [0.57142857, 0.85714286, 0.28571429, 0.28571429],
#        [0.57142857, 0.28571429, 0.14285714, 0.28571429],
#        [0.57142857, 0.42857143, 0.71428571, 0.71428571],
#        [0.71428571, 0.14285714, 0.        , 0.28571429],
#        [0.14285714, 1.        , 0.57142857, 0.57142857],
#        [0.85714286, 0.85714286, 0.42857143, 0.28571429],
#        [0.28571429, 0.57142857, 0.42857143, 0.14285714],
#        [0.28571429, 0.57142857, 0.28571429, 1.        ],
#        [0.71428571, 0.14285714, 0.57142857, 0.42857143],
#        [0.85714286, 0.14285714, 0.85714286, 1.        ],
#        [1.        , 0.42857143, 0.57142857, 0.14285714],
#        [0.14285714, 0.71428571, 0.42857143, 0.        ],
#        [0.71428571, 0.        , 0.71428571, 0.71428571],
# ...

# %%
### import pandas as pd 
df = pd.DataFrame(data=myData, columns=['clmn1', 'clmn2', 'clmn3', 'labels']) 
df
# Out:
#     clmn1  clmn2  clmn3  labels
# 0       6      2      6       4
# 1       8      8      1       4
# 2       4      7      4       8
# 3       5      7      3       3
# 4       5      3      2       3
# ..    ...    ...    ...     ...
# 95      1      5      1       5
# 96      2      4      3       2
# 97      5      7      1       7
# 98      7      3      6       8
# 99      2      6      6       8
#
# [100 rows x 4 columns]

# %%
X = df[['clmn1', 'clmn2', 'clmn3']]
y = df['labels']

# %%
from sklearn.model_selection import train_test_split # consider this as validation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)  #80percent  20 percent test
X_train.shape

#y_train.shape
#y_test.shape
#X_test.shape
# Out:
# (80, 3)

# %%
y_train
# Out:
# 79    3
# 56    6
# 31    7
# 97    7
# 72    8
#      ..
# 30    8
# 12    8
# 83    8
# 10    8
# 74    8
# Name: labels, Length: 70, dtype: int32

# %%
from sklearn.linear_model import LinearRegression as lm
model=lm().fit(X_train,y_train)
predictions=model.predict(X_test)
import matplotlib.pyplot as plt
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.scatter(y_test,predictions)

# %%
predictions
# Out:
# array([5.28834035, 4.79302486, 4.34788397, 4.05920532, 3.73272103,
#        4.79302486, 4.31853977, 4.78570191, 4.45921762, 4.19988317,
#        4.10571845, 4.10205697, 3.86355292, 4.06905128, 4.2965709 ,
#        5.27735592, 4.5607053 , 4.06172833, 4.79188639, 5.25167319,
#        4.40538154, 4.37237585, 4.66219298, 4.31967824, 5.08422653,
#        5.1355396 , 5.67484521, 3.96390213, 4.3943971 , 4.54719785])

# %%
import pandas as pd 
myData = np.random.randint(10, 99, (100 ,4)) # implement
myData # show the data
import pandas as pd 
df = pd.DataFrame(data=myData, columns=['clmn1', 'clmn2', 'clmn3', 'labels']) 
df.tail(7)
# Out:
#     clmn1  clmn2  clmn3  labels
# 93     92     69     90      13
# 94     88     16     70      80
# 95     47     96     34      16
# 96     32     71     41      87
# 97     60     24     82      40
# 98     88     85     56      88
# 99     56     68     31      27

# %%
df.max()
# Out:
# clmn1     98
# clmn2     98
# clmn3     95
# labels    98
# dtype: int32

# %%
df
# Out:
#     clmn1  clmn2  clmn3  labels
# 0      36     42     94      88
# 1      91     80     22      25
# 2      43     34     84      94
# 3      32     72     66      70
# 4      45     73     24      84
# ..    ...    ...    ...     ...
# 95     47     96     34      16
# 96     32     71     41      87
# 97     60     24     82      40
# 98     88     85     56      88
# 99     56     68     31      27
#
# [100 rows x 4 columns]

# %%
df.mean() # Returns the mean of all columns
df.corr() # Returns the correlation between columns in a data frame # how similar your columns with your target column
df.count() # Returns the number of non-null values in each data frame column
df.max() # Returns the highest value in each column
df.min() # Returns the lowest value in each column
df.median() # Returns the median of each column
df.std() #Returns the standard deviation of each column
# Out:
# clmn1     25.297924
# clmn2     25.566463
# clmn3     24.714769
# labels    26.107925
# dtype: float64
