# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #just another library for visualization
from matplotlib.ticker import PercentFormatter
sns.set()

# %%
# Load real estate data set for the histogram
df_real_estate = pd.read_csv("histogram_data.csv")

# %%
df_real_estate.head(20)
# Out:
#       ID  Building Type  Year of sale  Month of sale Type of property  \
# 0   1030              1        2005.0           11.0        Apartment
# 1   1029              1        2005.0           10.0        Apartment
# 2   2002              2        2007.0            7.0        Apartment
# 3   2031              2        2007.0           12.0        Apartment
# 4   1049              1        2004.0           11.0        Apartment
# 5   3011              3        2007.0            9.0        Apartment
# 6   3026              3        2007.0            9.0        Apartment
# 7   3023              3        2008.0            1.0        Apartment
# 8   1031              1        2006.0            6.0        Apartment
# 9   4023              4        2006.0            3.0        Apartment
# 10  1036              1        2004.0           10.0        Apartment
# 11  1046              1        2006.0            8.0        Apartment
# ...

# %%
plt.hist(df_real_estate["Price"])
plt.show() #the most basic style

# %%
# override the default matplotlib style, to avoid the gray background and grid
sns.set_style("dark") 
plt.figure(figsize = (8, 6)) # determine the size of the figure
plt.hist(df_real_estate["Price"], # the variable on which to create the histogram
         bins = 8, # create a histogram with 8 bins
         #you are allowed to alter bins above 
         color = "#9e1c2f")
plt.title("Distribution of Real Estate Prices based on Rubles", fontsize = 25, weight = "bold")
plt.xlabel("Price in (00's Rubles)",fontsize=20)  #its january now, Crypto is going down
plt.ylabel("Number of Properties",fontsize=20)
sns.despine()
 # removes the top and right border of our graph
plt.show()
#its a right skewed distribution

# %%
# HEX COLORS

#https://www.google.com/search?q=%23FF2343&sxsrf=AJOqlzV5FXaUfUjBe7lpyMoiMpdSW7uQwA%3A1678110049878&ei=Ye0FZNuONZfl7_UP5qWPyAw&ved=0ahUKEwibw6qLt8f9AhWX8rsIHebSA8kQ4dUDCA8&uact=5&oq=%23FF2343&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQAzoHCAAQHhCwAzoLCAAQBxAeELADEApKBAhBGAFQwgFYwgFgzARoAXAAeACAAY4BiAGOAZIBAzAuMZgBAKABAcgBAsABAQ&sclient=gws-wiz-serp

# %%
#its important to know how many `bins` you can possibly choose!
#its the most challenging task when you need a histogram
# increase or decrease `too much` or `too few` your number of histogram bins WILL SHOW YOU 
# approximately how many possible bins you might have
# check restaurant peaks, type google KFC and observe the busiest hours (i dont know why i gave alot of trash food examples)
# its a histogram!
# you can use when you have numerical data mostly
# for example qualitative informations that can be easily transformed into 1 -5 (numbers)

# %% [raw]
# HOMEWORK
# The data set for this assignment contains a survey of geodemographic features among 2000 participants. Your task is to create a histogram based on the Age variable in the data.
# -USE histogram_survey_data.csv
# -Decide on how many bins or what intervals lengths are appropriate for the histogram
# -What is the data distribution? What insight can you gain about the age/age groups of the participants in the survey?
# -Forget to format your chart by improving the colors and including proper chart labeling, then you are FIRED!
# - age Versus Number of participants
