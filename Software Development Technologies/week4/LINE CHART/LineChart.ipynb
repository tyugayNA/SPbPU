# %%
import pandas as pd #library for data manipulation
import matplotlib.pyplot as plt # library for visualization
import seaborn as sns # library for visualization 
sns.set() #this command sets the seaborn chart style as the default

from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %%
#load line chart data
df_spx_ftse_00_10 = pd.read_csv("line_chart_data.csv")
#stock market values (there is NO `white` salary in NO COMPANY OR FIRM that can be enough to make you RICH - just an opinion)
# i have GRAY SALARY or sometimes black :P
#S&P 500 simply largest companies listed in US - 
#FTSE 100 , 100 listed companies in UK
#we have date and those values as explained above

# %%
df_spx_ftse_00_10
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
#Convert 'Date' into datetime format. Otherwise it will be regarded as a simple string
#and it's highly likely that many operations or transformations on the date column won't have the desired result. 
#This is a crucial step in any time series analysis.
df_spx_ftse_00_10["new_date"] = pd.to_datetime(df_spx_ftse_00_10["Date"])
#use this function for date columns in general

# %%
df_spx_ftse_00_10["new_date"]
#new values are recorded in year month day Format
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 2865   2010-12-27
# 2866   2010-12-28
# 2867   2010-12-29
# 2868   2010-12-30
# 2869   2010-12-31
# Name: new_date, Length: 2870, dtype: datetime64[ns]

# %%
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["GSPC500"])
plt.show()

# %%
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["GSPC500"])
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["FTSE100"])
plt.show() # you have no idea what is this, you need to fix this

# %%
plt.figure(figsize = (20, 8)) #increase the size
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["GSPC500"])
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["FTSE100"])
plt.title("S&P vs FTSE Returns (2000 - 2010)", fontsize = 14, fontweight = "bold") #add a title and font
plt.ylabel("Returns") #add your y and x labels
plt.xlabel("Date")
plt.show()

# %%
plt.figure(figsize = (20, 8)) #increase the size
labels = ["S&P 500", "FTSE 100"] # legend labels list add legends
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["GSPC500"])
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["FTSE100"])
plt.title("S&P vs FTSE Returns (2000 - 2010)", fontsize = 14, fontweight = "bold") #add a title and font
plt.ylabel("Returns") #add your y and x labels
plt.xlabel("Date")
plt.legend(labels = labels, fontsize = "large") #print legends in LARGE FORM
plt.show()

# %%
#introduce a new data frame for a specific time frame. Starts 07/01/2008 and ends 12/31/2008 here
#slice your data into specific time frame 
#however you want you can choose
df_spx_ftse_H2_08 = df_spx_ftse_00_10[(df_spx_ftse_00_10.new_date >= '2005-11-15') &
                                      (df_spx_ftse_00_10.new_date <= '2005-12-31')]

# %%
df_spx_ftse_H2_08 # created new dataframe for timeframe in 2008
# Out:
#             Date   GSPC500   FTSE100   new_date
# 1531  11/15/2005 -0.000777  0.000897 2005-11-15
# 1532  11/16/2005 -0.003850 -0.005558 2005-11-16
# 1533  11/17/2005  0.001790 -0.001765 2005-11-17
# 1534  11/18/2005  0.009414  0.005525 2005-11-18
# 1535  11/21/2005  0.004401  0.007125 2005-11-21
# 1536  11/22/2005  0.005271 -0.000182 2005-11-22
# 1537  11/23/2005  0.005084  0.003510 2005-11-23
# 1538  11/24/2005  0.000000  0.002628 2005-11-24
# 1539  11/25/2005  0.003473 -0.003742 2005-11-25
# 1540  11/28/2005  0.002086  0.002323 2005-11-28
# 1541  11/29/2005 -0.008508 -0.008400 2005-11-29
# 1542  11/30/2005  0.000016  0.002483 2005-11-30
# 1543   12/1/2005 -0.006362 -0.012347 2005-12-01
# 1544   12/2/2005  0.012157  0.011598 2005-12-02
# 1545   12/5/2005  0.000324  0.007656 2005-12-05
# 1546   12/6/2005 -0.002363 -0.003202 2005-12-06
# 1547   12/7/2005  0.001276  0.005154 2005-12-07
# 1548   12/8/2005 -0.005009 -0.001805 2005-12-08
# 1549   12/9/2005 -0.001217  0.000416 2005-12-09
# ...

# %%
plt.figure(figsize = (20, 8))

plt.plot(df_spx_ftse_H2_08["new_date"], df_spx_ftse_H2_08["GSPC500"], color = "crimson")
plt.plot(df_spx_ftse_H2_08["new_date"], df_spx_ftse_H2_08["FTSE100"], color = "blue")
plt.title("S&P vs FTSE Returns (H2 2005)", fontsize = 14, fontweight = "bold") #updated here
plt.ylabel("Returns",fontsize = 20)
plt.xlabel("Date",fontsize = 20)
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %% [raw]
# Your Homework task is to create a line chart using the new index data which is from 2010 until 2020.
# USE: returns1020.csv
# After you’ve created your line chart:
# Think about narrowing down the time frame to a more specific period.
#
# #remember, you can get timeframes from a data so your results(visuzalizations) will look COOL AND UNDERSTANDABLE

# %%
#good for tracking several different variables 
#dont use when you have too many categories ( your chart will look like a spaghetti)
#not necessary to start your y axis from 0!
