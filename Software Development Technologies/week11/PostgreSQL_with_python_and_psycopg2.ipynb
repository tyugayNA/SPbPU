# %%
import psycopg2 as pg2

# %%
conn = pg2.connect(database='dvdrental',user='postgres',password='azwraith')
#wow it works, login:
# postgres is default username for postgresSQL

# %%
#now retrieve the cursor
cur = conn.cursor()
#select * from film order by length asc limit 1000')

# %%
cur.execute('select * from film where release_year = 2006 limit 15')


#you must run the pgadmin Interface also!

# %%
cur.fetchmany(10)
# 10 elements
# Out:
# [(133,
#   'Chamber Italian',
#   'A Fateful Reflection of a Moose And a Husband who must Overcome a Monkey in Nigeria',
#   2006,
#   1,
#   7,
#   Decimal('4.99'),
#   117,
#   Decimal('14.99'),
#   'NC-17',
#   datetime.datetime(2013, 5, 26, 14, 50, 58, 951000),
#   ['Trailers'],
#   "'chamber':1 'fate':4 'husband':11 'italian':2 'monkey':16 'moos':8 'must':13 'nigeria':18 'overcom':14 'reflect':5"),
#  (384,
#   'Grosse Wonderful',
#   'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia',
#   2006,
#   1,
#   5,
#   Decimal('4.99'),
#   49,
#   Decimal('19.99'),
#   'R',
#   datetime.datetime(2013, 5, 26, 14, 50, 58, 951000),
#   ['Behind the Scenes'],
#   "'australia':18 'cat':8 'drama':5 'epic':4 'explor':11 'gross':1 'moos':16 'must':13 'redeem':14 'wonder':2"),
#  (8,
#   'Airport Pollock',
#   'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India',
#   2006,
#   1,
#   6,
#   Decimal('4.99'),
#   54,
#   Decimal('15.99'),
# ...

# %%
cur.fetchall()
# gel all
# Out:
# [(7,
#   'Airplane Sierra',
#   'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat',
#   2006,
#   1,
#   6,
#   Decimal('4.99'),
#   62,
#   Decimal('28.99'),
#   'PG-13',
#   datetime.datetime(2013, 5, 26, 14, 50, 58, 951000),
#   ['Trailers', 'Deleted Scenes'],
#   "'airplan':1 'boat':20 'butler':11,16 'discov':14 'hunter':8 'jet':19 'must':13 'saga':5 'sierra':2 'touch':4"),
#  (9,
#   'Alabama Devil',
#   'A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat',
#   2006,
#   1,
#   3,
#   Decimal('2.99'),
#   114,
#   Decimal('21.99'),
#   'PG-13',
#   datetime.datetime(2013, 5, 26, 14, 50, 58, 951000),
#   ['Trailers', 'Deleted Scenes'],
#   "'administr':9 'alabama':1 'boat':23 'databas':8 'devil':2 'jet':22 'mad':12,18 'must':15 'outgun':16 'panorama':5 'scientist':13,19 'thought':4"),
#  (10,
#   'Aladdin Calendar',
# ...

# %%
# read in your SQL query results using pandas  #EASIST AND MOST ACCURATE WAY
import pandas as pd
dataframe = pd.read_sql("""
            select * from film where replacement_cost >= 15 limit 100;
            """, con = conn)
# return your first five rows
dataframe
# Out:
# C:\Users\MONSTER\AppData\Local\Temp/ipykernel_3928/2641072300.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dataframe = pd.read_sql("""
#     film_id             title  \
# 0       384  Grosse Wonderful
# 1         8   Airport Pollock
# 2         1  Academy Dinosaur
# 3         3  Adaptation Holes
# 4         4  Affair Prejudice
# ..      ...               ...
# 95      121       Carol Texas
# 96      123  Casablanca Super
# 97      124  Casper Dragonfly
# 98      125   Cassidy Wyoming
# 99      129        Cause Date
#
#                                           description  release_year  \
# 0   A Epic Drama of a Cat And a Explorer who must ...          2006
# 1   A Epic Tale of a Moose And a Girl who must Con...          2006
# 2   A Epic Drama of a Feminist And a Mad Scientist...          2006
# ...

# %%
dataframe.columns
# Out:
# Index(['film_id', 'title', 'description', 'release_year', 'language_id',
#        'rental_duration', 'rental_rate', 'length', 'replacement_cost',
#        'rating', 'last_update', 'special_features', 'fulltext'],
#       dtype='object')

# %%
#always close it
conn.close()

# %%
#select * from film where release_year = 2006 limit 15

# %% [markdown]
# ####
