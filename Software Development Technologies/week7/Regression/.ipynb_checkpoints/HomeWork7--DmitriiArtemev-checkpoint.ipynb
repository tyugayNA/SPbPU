# %%
# a useful link
#  https://scikit-learn.org/stable/modules/model_evaluation.html
#special request as promised

# %% [raw]
# https://www.kaggle.com/quantbruce/real-estate-price-prediction
#
# The dataset link for you    (real estate csv)   SORRY my underscore button is not working(

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Real estate.csv')
origdata=data
data.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
data.head() # lets predict `Y house price unit area`
# remember that removing `No` column can increase your result
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %%
data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
y = data.iloc[:,-1]
print(y)
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
data.drop('Y house price of unit area', axis=1, inplace=True)  # drop columns
data.drop('No', axis=1, inplace=True)  # drop columns
data.drop('X1 transaction date', axis=1, inplace=True)  # drop columns
data.drop('X5 latitude', axis=1, inplace=True)  # drop columns
data.drop('X6 longitude', axis=1, inplace=True)  # drop columns

# %%
data
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores
# 0                                 10
# 1                                  9
# 2                                  5
# 3                                  5
# 4                                  5
# ..                               ...
# 409                                0
# 410                                9
# 411                                7
# 412                                5
# 413                                9
#
# [414 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,y,test_size=0.2,random_state=2)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %% [raw]
# MAE calculates the ABSOLUTE difference between actual and predicted values and sum!

# %%
from IPython.display import Image
Image(filename='mae.jpg')  # Never use accuracy or confusion matrix when you have Regression task!

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 6.362370630628733

# %% [raw]
# Mean squared error finds the SQUARED difference between actual and predicted value.

# %%
from IPython.display import Image
Image(filename='mse.jpg')

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 119.36009326395077

# %%
from IPython.display import Image
Image(filename='rmse.jpg')

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 10.925204495292103

# %%
from IPython.display import Image
Image(filename='r2.jpg')

# %%
from sklearn.metrics import r2_score  # It explains how well a model performs when replicating the observed outcomes
r2 = r2_score(y_test,y_pred)
print(r2)  #remember its near to 1 meaning its good
# Out:
# 0.4615959935866515

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 8))
plt.plot(y_test.to_numpy(dtype=object)[:100], color = "purple")
plt.plot(y_pred[:100], color = "green")
plt.title("green(predictions) VS purple(actual) prices", fontsize = 14, fontweight = "bold") #updated here
plt.ylabel("Y",fontsize = 20)
plt.xlabel("X",fontsize = 20)

plt.show()

# %%
y_test
# Out:
# 147    43.2
# 217    40.8
# 277    27.7
# 32     34.2
# 182    23.6
#        ...
# 223    42.3
# 205    21.4
# 40     15.9
# 17     37.4
# 358    45.1
# Name: Y house price of unit area, Length: 83, dtype: float64

# %%
#PERHAPS YOU ARE BORED OF STUPID LINEAR REGRESSION, LETS TRY SOMETHING COOL

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr_y_predict = gbr.predict(X_test)

print("R-squared value of GradientBoostingRegressor: {sc}".format(sc = gbr.score(X_test, y_test)))
print("The mean squared error of GradientBoostingRegressor: {}".format(mean_squared_error(y_test, gbr_y_predict)))
print("The mean absoluate error of GradientBoostingRegressor: {}".format(mean_absolute_error(y_test,gbr_y_predict)))
# Out:
# R-squared value of GradientBoostingRegressor: 0.5229343316022077
# The mean squared error of GradientBoostingRegressor: 105.76184797048668
# The mean absoluate error of GradientBoostingRegressor: 5.309438457713661

# %%
plt.figure(figsize=(25,10))
plt.plot(y_test.to_numpy(dtype=object)[:100],c='yellow')
plt.plot(gbr_y_predict[:100],c='black')  #predicts
plt.legend(['real','predict'],fontsize="large")
plt.title('The result of GradientBoostingRegressor')
# Out:
# Text(0.5, 1.0, 'The result of GradientBoostingRegressor')

# %%
#perhaps lets add MINMAX SCALING AND SEE WHATS GONNA HAPPEEN

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(data=scaler.transform(X_train),columns = X_train.columns,index=X_train.index)
X_test = pd.DataFrame(data=scaler.transform(X_test),columns = X_test.columns,index=X_test.index)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=500)
rfr.fit(X_train,y_train)
rfr_y_predict = rfr.predict(X_test)

print("R-squared value of RandomForestRegressor: {sc}".format(sc = rfr.score(X_test, y_test)))
print("The mean squared error of RandomForestRegressor: {}".format(mean_squared_error(y_test, rfr_y_predict)))
print("The mean absoluate error of RandomForestRegressor: {}".format(mean_absolute_error(y_test,rfr_y_predict)))
#BETTER
# Out:
# R-squared value of RandomForestRegressor: 0.5404398111271671
# The mean squared error of RandomForestRegressor: 101.88101565155853
# The mean absoluate error of RandomForestRegressor: 4.723029137502376

# %%
plt.figure(figsize=(25,10))
plt.plot(y_test.to_numpy(dtype=object)[:200],c='blue')
plt.plot(rfr_y_predict[:200],c='red')
plt.annotate(
# Label and coordinate
'outlier!', xy=(50, 115), xytext=(20, 120),

# Custom arrow
arrowprops=dict(facecolor='black', shrink=0.1)
)
plt.legend(['real','predict'],fontsize="large")
plt.title('The result of RandomForestRegressor')
# Out:
# Text(0.5, 1.0, 'The result of RandomForestRegressor')

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    #print('______')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=1000)  # maybe parameter tuning
rf_reg.fit(X_train, y_train)

test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)


print('Testing set evaluation:\n-------')
print_evaluate(y_test, test_pred)
print('\n')
print('Training set evaluation:\n-------')
print_evaluate(y_train, train_pred)
#congratulations
# Out:
# Testing set evaluation:
# -------
# MAE: 4.7245112876982835
# MSE: 101.98218802548875
# RMSE: 10.098623075721202
# R2 Square 0.5399834474467038
#
#
# Training set evaluation:
# -------
# MAE: 2.104902705026598
# MSE: 8.645451165875748
# RMSE: 2.9403148072741714
# R2 Square 0.9501304795898378

# %%
plt.figure(figsize=(25,10))
plt.plot(y_test.to_numpy(dtype=object)[:100],c='pink')
plt.plot(test_pred[:100],c='black')  #predicts
plt.annotate(

'Outlier!', xy=(50, 115), xytext=(0, 100),
 
# Custom arrow
arrowprops=dict(facecolor='red', shrink=0.05)
)
plt.legend(['real','predict'],fontsize="large")
plt.title('The result of RandomForestRegressor')
# Out:
# Text(0.5, 1.0, 'The result of RandomForestRegressor')

# %% [markdown]
# # HOMEWORK #7 STARTS HERE

# %%
#Now let's try to find incorrect values, aka outliers.

# %%
dataset = pd.read_csv("Real estate.csv")
dataset = dataset.drop('No',axis=1)
X = dataset
#X = dataset.drop('Y house price of unit area',axis=1)
Y = dataset['Y house price of unit area']

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import RidgeCV

ridge = RidgeCV(alphas=np.logspace(-50, 50, num=5)).fit(X, Y)
#Here i've tried many other logspace params like logspace(-5, 5, num=5) and so one.
#But this one i like more
importance = np.abs(ridge.coef_)
feature_names = np.array(X.columns)
plt.bar(height=importance, x=feature_names)
plt.xticks(fontsize=8, rotation = -90)
plt.title("Feature importances via coefficients")
plt.show()

# %%
#as we can see column x3 are important, let see it's values

# %%
X['X3 distance to the nearest MRT station'].hist(bins=400)
# Out:
# <AxesSubplot:>

# %%
X['X3 distance to the nearest MRT station'].describe()
# Out:
# count     414.000000
# mean     1083.885689
# std      1262.109595
# min        23.382840
# 25%       289.324800
# 50%       492.231300
# 75%      1454.279000
# max      6488.021000
# Name: X3 distance to the nearest MRT station, dtype: float64

# %%
#look at the mean and max values - it's too big difference between them, lets' clean up unnormal values (outliers)

# %%
from sklearn.ensemble import IsolationForest
iso = IsolationForest()
y_outliers = iso.fit_predict(X)

# %%
for i in range(len(y_outliers)):
    if y_outliers[i] == -1:
        X.drop(i, inplace = True)

# %%
X.shape
# Out:
# (341, 7)

# %%
X['X3 distance to the nearest MRT station'].hist(bins=400)
# Out:
# <AxesSubplot:>

# %%
Y=X['Y house price of unit area']
X.drop('Y house price of unit area', axis=1, inplace=True)
#X.drop('X1 transaction date', axis=1, inplace=True)
#X.drop('X5 latitude', axis=1, inplace=True)
#X.drop('X6 longitude', axis=1, inplace=True)
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [341 rows x 6 columns]

# %%
Y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 341, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2, shuffle=True)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (20, 8))
plt.plot(y_test.to_numpy(dtype=object)[:100], color = "purple")
plt.plot(y_pred[:100], color = "green")
plt.title("green(predictions) VS purple(actual) prices", fontsize = 14, fontweight = "bold") #updated here
plt.ylabel("Y",fontsize = 20)
plt.xlabel("X",fontsize = 20)

plt.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 5.502828708056319

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 47.826023902779546

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 6.915636189301715

# %%
from sklearn.metrics import r2_score  # It explains how well a model performs when replicating the observed outcomes
r2 = r2_score(y_test,y_pred)
print(r2)  #remember its near to 1 meaning its good
# Out:
# 0.680093431665839

# %%
#R2 still low uhhh, but fills better, lets do Forrest Regression and compare test and train params

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=1000)  # maybe parameter tuning
rf_reg.fit(X_train, y_train)
test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)
print('Testing set evaluation:\n-------')
print_evaluate(y_test, test_pred)
print('\n')
print('Training set evaluation:\n-------')
print_evaluate(y_train, train_pred)
#congratulations
# Out:
# Testing set evaluation:
# -------
# MAE: 4.204579403036573
# MSE: 30.67902284688443
# RMSE: 5.5388647615630076
# R2 Square 0.7947891102395881
#
#
# Training set evaluation:
# -------
# MAE: 1.5142165056022197
# MSE: 4.223071907195562
# RMSE: 2.055011412911267
# R2 Square 0.9623606361835818

# %%
#WOW look at R2 of Testing set! It's done! Let's do some plot

# %%
plt.figure(figsize=(25,10))
plt.plot(y_test.to_numpy(dtype=object)[:len(y_test)],c='pink')
plt.plot(test_pred[:len(test_pred)],c='black')  #predicts
plt.annotate(

'Outlier!', xy=(50, 115), xytext=(0, 100),
 
# Custom arrow
arrowprops=dict(facecolor='red', shrink=0.05)
)
plt.legend(['real','predict'],fontsize="large")
plt.title('The result of RandomForestRegressor')
# Out:
# Text(0.5, 1.0, 'The result of RandomForestRegressor')

# %%
#PS: BUUUUUT what if we will add some extra specific data at our original dataset? let's try Data Augmentation
#with clearing "Y house price of unit area" column from unnormal values (outliers)

# %%
import seaborn as sns
import pandas as pd
from ctgan import CTGAN

data = pd.read_csv('Real estate.csv')
discrete_columns = ['X2 house age', 'X3 distance to the nearest MRT station', 'X4 number of convenience stores', 
                    'Y house price of unit area']
#data.drop('Y house price of unit area', axis=1, inplace=True)  # drop columns
data.drop('No', axis=1, inplace=True)  # drop columns
#data.drop('X1 transaction date', axis=1, inplace=True)  # drop columns
#data.drop('X5 latitude', axis=1, inplace=True)  # drop columns
#data.drop('X6 longitude', axis=1, inplace=True)  # drop columns
print('Original data:\n-------')
data.head()
# Out:
# Original data:
# -------
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
#clean data using quantile
import scipy.stats as stats

Q1 = data.quantile(q=.25)
Q3 = data.quantile(q=.75)
IQR = data.apply(stats.iqr)

#only keep rows in dataframe that have values within 1.5*IQR of Q1 and Q3
data_clean = data[~((data < (Q1-1.5*IQR)) | (data > (Q3+1.5*IQR))).any(axis=1)]

#find how many rows are left in the dataframe 
data_clean.shape
# Out:
# (371, 7)

# %%
#ctgan = CTGAN()
ctgan = CTGAN(epochs=5)
ctgan.fit(data_clean, discrete_columns)

# %%
new_data = ctgan.sample(3*len(data_clean))
#yeap, let's 4x data
print('CTGan data:\n-------')
new_data.head()
# Out:
# CTGan data:
# -------
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0          2013.527468          43.8                                942.4664
# 1          2012.867517           5.7                                274.0144
# 2          2013.031996          30.6                               1783.1800
# 3          2013.477399          13.7                                552.4371
# 4          2012.880892          10.3                                336.0532
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                6    24.966751    121.540434
# 1                                7    24.969074    121.519870
# 2                                4    24.946508    121.538894
# 3                                2    24.961811    121.530919
# 4                                1    24.961951    121.532415
#
#    Y house price of unit area
# 0                        63.9
# 1                        27.3
# 2                        23.9
# 3                        30.6
# 4                        24.8

# %%
data_clean.append(new_data, ignore_index = True)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11400\2233306410.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_clean.append(new_data, ignore_index = True)
#       X1 transaction date  X2 house age  \
# 0             2012.917000          32.0
# 1             2012.917000          19.5
# 2             2013.583000          13.3
# 3             2013.500000          13.3
# 4             2012.833000           5.0
# ...                   ...           ...
# 1479          2012.885956          38.0
# 1480          2012.826902          12.4
# 1481          2012.840188          13.6
# 1482          2013.011250          38.2
# 1483          2012.799864          11.0
#
#       X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                   84.87882                               10
# 1                                  306.59470                                9
# 2                                  561.98450                                5
# 3                                  561.98450                                5
# 4                                  390.56840                                5
# ...                                      ...                              ...
# 1479                               281.20500                                3
# 1480                               383.71290                                6
# 1481                              1828.31900                                2
# 1482                              1156.77700                               10
# 1483                               368.13630                               10
#
#       X5 latitude  X6 longitude  Y house price of unit area
# 0       24.982980    121.540240                        37.9
# 1       24.980340    121.539510                        42.2
# 2       24.987460    121.543910                        47.3
# 3       24.987460    121.543910                        54.8
# 4       24.979370    121.542450                        43.1
# ...           ...           ...                         ...
# 1479    24.976239    121.555438                        39.7
# 1480    24.977157    121.551384                        47.1
# 1481    24.964907    121.515308                        47.0
# 1482    24.982131    121.538472                        42.1
# 1483    24.972897    121.532238                        56.3
#
# [1484 rows x 7 columns]

# %%
y = data_clean['Y house price of unit area']
data_clean.drop('Y house price of unit area', axis=1, inplace=True)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11400\1565176115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean.drop('Y house price of unit area', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data_clean,y,test_size=0.3,random_state=2, shuffle=True)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=1000)  # maybe parameter tuning
rf_reg.fit(X_train, y_train)
test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)
print('Testing set evaluation:\n-------')
print_evaluate(y_test, test_pred)
print('\n')
print('Training set evaluation:\n-------')
print_evaluate(y_train, train_pred)
# Out:
# Testing set evaluation:
# -------
# MAE: 4.3449927065617695
# MSE: 32.62663409973124
# RMSE: 5.711972872811218
# R2 Square 0.7367983636311968
#
#
# Training set evaluation:
# -------
# MAE: 1.742188092939865
# MSE: 5.534162536849132
# RMSE: 2.352480082136538
# R2 Square 0.9605353655366433

# %%
plt.figure(figsize=(25,10))
plt.plot(y_test.to_numpy(dtype=object)[:len(y_test)],c='pink')
plt.plot(test_pred[:len(test_pred)],c='black')  #predicts
plt.annotate(

'Outlier!', xy=(50, 115), xytext=(0, 100),
 
# Custom arrow
arrowprops=dict(facecolor='red', shrink=0.05)
)
plt.legend(['real','predict'],fontsize="large")
plt.title('The result of RandomForestRegressor')
# Out:
# Text(0.5, 1.0, 'The result of RandomForestRegressor')

# %%
#Done!
